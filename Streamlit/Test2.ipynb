# %%
import pysd
import xarray as xr
import numpy as np

# %%
model = pysd.load('09032024_PVMat.py')

output = model.run(params={"Time":2026,
                           "INITIAL TIME": 2025,
                           "FINAL TIME": 2027,
                          "PV Future Production User Input":0,
                          "Planned Annual Incremental Capacity":0,
                          "PV Deployment Initial Incremental": 0,
                          "Current Annual PV Deployment":0,
                          "Planned Annual Incremental Capacity User Input":0,
                          })
# Out:
# C:\Users\Chenyang\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pysd\py_backend\model.py:1140: UserWarning: Replacing a variable by a constant value.
#   warnings.warn("Replacing a variable by a constant value.")

# %%
output.to_csv("output_test.csv")

# %%
output["Weibull PDF Regular Loss[Y2025]"]
# Out:
# time
# 2023    4.643700e-07
# 2024    4.643700e-07
# 2025    4.643700e-07
# 2026    4.643700e-07
# 2027    4.643700e-07
# 2028    4.643700e-07
# 2029    4.643700e-07
# 2030    4.643700e-07
# 2031    4.643700e-07
# 2032    4.643700e-07
# 2033    4.643700e-07
# 2034    4.643700e-07
# 2035    4.643700e-07
# 2036    4.643700e-07
# 2037    4.643700e-07
# 2038    4.643700e-07
# 2039    4.643700e-07
# 2040    4.643700e-07
# 2041    4.643700e-07
# 2042    4.643700e-07
# 2043    4.643700e-07
# 2044    4.643700e-07
# 2045    4.643700e-07
# 2046    4.643700e-07
# 2047    4.643700e-07
# 2048    4.643700e-07
# 2049    4.643700e-07
# 2050    4.643700e-07
# Name: Weibull PDF Regular Loss[Y2025], dtype: float64

# %%
xr.DataArray(np.nan, {"PVDev": 2023}, ["PVDev"])
# Out:
# <xarray.DataArray (PVDev: 1)>
# array([nan])
# Coordinates:
#     PVDev    int32 2023

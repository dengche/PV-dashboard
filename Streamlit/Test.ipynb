# %%
import pysd
import matplotlib.pyplot as plt
import numpy as np

# %%
a= pysd.read_xmile("test.stmx")

# %%
# Define the functions for delay input, delay time, and initial value
def delay_input():
    return np.random.random()  # Example input function returning random values

def delay_time():
    return 3  # Delay time of 3 time steps

def initial_value():
    return 0  # Initial value before any updates

def tstep():
    return 1  # Time step of 1

# Create an instance of DelayFixed
delay_fixed = DelayFixed(delay_input, delay_time, initial_value, tstep, "MyDelay")

# Initialize the delay line
delay_fixed.initialize()

# Simulate a few steps and output the function's delayed result
for _ in range(10):  # Simulate 10 time steps
    delay_fixed.update(None)  # Update the delay state
    output = delay_fixed()  # Get the current output (delayed value)
    print(f"Delayed Output: {output}")
# Out:
# Delayed Output: 0
# Delayed Output: 0
# Delayed Output: 0.32299716273835455
# Delayed Output: 0.6166240569367462
# Delayed Output: 0.683218656934198
# Delayed Output: 0.7306104720197268
# Delayed Output: 0.96125213237027
# Delayed Output: 0.9183655324582513
# Delayed Output: 0.4615256614789569
# Delayed Output: 0.13120622903211165

# %%
delay_fixed

# %%
delay.initialize()

# %%
delay.

# %%
delay.state
# Out:
# 1

# %%
delay.update(None)
delay()
# Out:
# 1

# %%
delay.update()
delay()
# Out:
# 1

# %%
x = range(10)

# %%
def derivative():
    return 2  # This could be any function representing d/dt

# Define an initial value for the stock
def initial_value():
    return 8.9  # Initial stock value

# Create an Integ object
stock = Integ(derivative, initial_value, "stock_name")

# Initialize the stock
stock.initialize()

# Access the current state of the stock
print("Initial state:", stock.state)  # Should print 10

# Simulate an update (this would typically be done within a loop with time steps)
stock.state += stock.ddt()  # Simple Euler integration step
print("Updated state:", stock.state)  # Should print 12
# Out:
# Initial state: 8.9
# Updated state: 10.9

# %%
delay()
# Out:
# 0

# %%
a = DelayFixed(1,1,1,tstep=1,py_name="1")

# %%
a.initialize()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 a.initialize()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pysd\py_backend\statefuls.py:375, in DelayFixed.initialize(self, init_val)
#     374 def initialize(self, init_val=None):
# --> 375     order = max(self.delay_time_func()/self.tstep(), 1)
#     377     if order != int(order):
#     378         warnings.warn(
#     379             self.py_name + '\n'
#     380             + 'Casting delay order from %f to %i' % (
#     381                 order, round(order + SMALL_VENSIM)))
#
# TypeError: 'int' object is not callable

# %%
model = pysd.load('09032024_PVMat.py')
output = model.run(params={"Time":2027,
                          "PV Future Production User Input":0,
                          "Planned Annual Incremental Capacity":0,
                          "PV Deployment Initial Incremental": 0,
                          "Current Annual PV Deployment":0,
                          "Planned Annual Incremental Capacity User Input":0,
                          })
# Out:
# C:\Users\Chenyang\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pysd\py_backend\model.py:1140: UserWarning: Replacing a variable by a constant value.
#   warnings.warn("Replacing a variable by a constant value.")

# %%
output
# Out:
#       INITIAL TIME  FINAL TIME  TIME STEP  SAVEPER  Annual Material Demand  \
# time
# 2023          2023        2050          1        1            9.221148e+06
# 2024          2023        2050          1        1            1.183236e+07
# 2025          2023        2050          1        1            1.183238e+07
# 2026          2023        2050          1        1            1.183239e+07
# 2027          2023        2050          1        1            1.183241e+07
# 2028          2023        2050          1        1            1.183242e+07
# 2029          2023        2050          1        1            1.183244e+07
# 2030          2023        2050          1        1            1.183246e+07
# 2031          2023        2050          1        1            1.183247e+07
# 2032          2023        2050          1        1            1.183249e+07
# 2033          2023        2050          1        1            1.183251e+07
# ...

# %%
# !streamlit run 06032025materials_dashboard.py
